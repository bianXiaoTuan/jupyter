# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame({
        'A' : 1.,
        'B' : pd.date_range('20130101', periods=5),
        'C' : np.array([3]*5, dtype='int32'),
        'D' : np.arange(5)
    })

# head
print df

print df.head()
print df.head(1)
print df.tail(3)

print '-' * 50

# index
print df.index

print '-' * 50

# columns
print df.columns

print '-' * 50

# values
print df.values

print '-' * 50

# describe()
print df.describe()

print '-' * 50

# T
print df.T

print '-' * 50

# sort
print df.sort_index(axis=1, ascending=False)

print '-' * 50

print df.sort_values(by='B')
# Out:
#      A          B  C  D
# 0  1.0 2013-01-01  3  0
# 1  1.0 2013-01-02  3  1
# 2  1.0 2013-01-03  3  2
# 3  1.0 2013-01-04  3  3
# 4  1.0 2013-01-05  3  4
#      A          B  C  D
# 0  1.0 2013-01-01  3  0
# 1  1.0 2013-01-02  3  1
# 2  1.0 2013-01-03  3  2
# 3  1.0 2013-01-04  3  3
# 4  1.0 2013-01-05  3  4
#      A          B  C  D
# 0  1.0 2013-01-01  3  0
#      A          B  C  D
# 2  1.0 2013-01-03  3  2
# 3  1.0 2013-01-04  3  3
# 4  1.0 2013-01-05  3  4
# --------------------------------------------------
# RangeIndex(start=0, stop=5, step=1)
# --------------------------------------------------
# Index([u'A', u'B', u'C', u'D'], dtype='object')
# --------------------------------------------------
# [[1.0 Timestamp('2013-01-01 00:00:00') 3 0]
#  [1.0 Timestamp('2013-01-02 00:00:00') 3 1]
#  [1.0 Timestamp('2013-01-03 00:00:00') 3 2]
#  [1.0 Timestamp('2013-01-04 00:00:00') 3 3]
#  [1.0 Timestamp('2013-01-05 00:00:00') 3 4]]
# --------------------------------------------------
# ...
